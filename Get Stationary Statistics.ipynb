# %%
from analysis_tools.stationary_stats import Stationary_Statistics
# %matplotlib inline

# %%
import os
data_set_files = os.listdir("data_retrieval/csvs")
data_set_files
# Out:
# ['no_pd_filtered_2019.csv',
#  'detroit_pd_filtered_2019.csv',
#  'richmond_pd_filtered_2014_2018.csv',
#  'boulder_fire_rescue_2015_2019.csv',
#  'nyc_fd_2018.csv',
#  'cin_pd_2019.csv',
#  'nyc_ems_2019.csv',
#  'first_unit_priority_sf_fire_2019.csv',
#  'tempe_als_2018.csv']

# %%
data_set_base = "/home/blakemoss/911_modeling/data_retrieval/csvs/"
for data_set_name in data_set_files:
    print(data_set_name)
    data_full_path = data_set_base + data_set_name
    stats = Stationary_Statistics(data_set_name, data_full_path)
    #print(stats.auto_correlation_compare())
    #stats.auto_correlation_arrival_counts()
    #stats.show_avg_number_of_arrivals_per_hour_graph()
    stats.show_avg_number_of_arrivals_per_minute_graph()
# Out:
# no_pd_filtered_2019.csv
# ...
# no_pd_filtered_2019.csv entered_to_cad
# no_pd_filtered_2019.csv first_unit_enroute
# no_pd_filtered_2019.csv first_unit_onscene
# no_pd_filtered_2019.csv incident_closed
# detroit_pd_filtered_2019.csv
# ...
# detroit_pd_filtered_2019.csv call_received
# detroit_pd_filtered_2019.csv entered_to_cad
# detroit_pd_filtered_2019.csv first_unit_enroute
# detroit_pd_filtered_2019.csv first_unit_onscene
# detroit_pd_filtered_2019.csv incident_closed
# richmond_pd_filtered_2014_2018.csv
# ...
# richmond_pd_filtered_2014_2018.csv entered_to_cad
# richmond_pd_filtered_2014_2018.csv first_unit_enroute
# richmond_pd_filtered_2014_2018.csv first_unit_onscene
# richmond_pd_filtered_2014_2018.csv incident_closed
# boulder_fire_rescue_2015_2019.csv
# ...
# boulder_fire_rescue_2015_2019.csv call_received
# boulder_fire_rescue_2015_2019.csv first_unit_assigned
# boulder_fire_rescue_2015_2019.csv first_unit_enroute
# boulder_fire_rescue_2015_2019.csv first_unit_onscene
# ...

# %%
#data_set_base = "/home/blakemoss/911_modeling/data_retrieval/csvs/"
#data_set_name = "first_unit_priority_sf_fire_2019.csv"
#data_full_path = data_set_base + data_set_name
#stats = Stationary_Statistics(data_set_name, data_full_path)

# %%
#stats.calculate_avg_arrival_rates_per_hour()

# %%
#stats.calculate_arrival_rates_per_hour()
