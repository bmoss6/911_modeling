# %%
import dask.dataframe as dd
import pandas as pd
import os
import csv
import traceback
import logging
import numpy as np
import geopandas as gp
import scipy.stats as st
import matplotlib.pyplot as plt
dataset_path = "/home/blakemoss/911_modeling/data_retrieval/csvs/no_pd_2019.csv"
df = dd.read_csv(dataset_path, dtype={'zip': 'object'})

# %%
df = df.compute()
df = df[df['selfinitiated']=='N']

# %%
df
# Out:
#        nopd_item type_               typetext priority     mapx    mapy  \
# 1       A0000219    94    DISCHARGING FIREARM       2D  3686821  536822
# 2       A0000319   21N        NOISE COMPLAINT       1G  3673664  522627
# 3       A0000419    94    DISCHARGING FIREARM       2D  3663805  532324
# 4       A0000519   103    DISTURBANCE (OTHER)       2A  3681969  553869
# 5       A0000619   94F              FIREWORKS       1A  3697681  536926
# ...          ...   ...                    ...      ...      ...     ...
# 229001  L4055019   94F              FIREWORKS       1A  3697793  553724
# 229003  L4055219    94    DISCHARGING FIREARM       2D  3692829  540992
# 229004  L4055319   62A  BURGLAR ALARM, SILENT       2E  3688232  542444
# 229006  L4055519   62A  BURGLAR ALARM, SILENT       2E  3685424  556751
# 229007  L4055619   103    DISTURBANCE (OTHER)       1C  3707204  559605
#
#                      timecreate             timedispatch  \
# ...

# %%
df.to_csv("no_pd_filtered_2019.csv")
